# %%
# !pip install -r requirement.txt
# Out:
# Requirement already satisfied: numpy in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from -r requirement.txt (line 1)) (2.1.3)
# Requirement already satisfied: pandas in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from -r requirement.txt (line 2)) (2.3.3)
# Requirement already satisfied: scikit-learn in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from -r requirement.txt (line 3)) (1.7.2)
# Requirement already satisfied: imbalanced-learn in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from -r requirement.txt (line 4)) (0.14.0)
# Requirement already satisfied: matplotlib in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from -r requirement.txt (line 5)) (3.10.0)
# Requirement already satisfied: seaborn in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from -r requirement.txt (line 6)) (0.13.2)
# Requirement already satisfied: plotly in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from -r requirement.txt (line 7)) (6.4.0)
# Requirement already satisfied: joblib in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from -r requirement.txt (line 8)) (1.5.2)
# Requirement already satisfied: pyyaml in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from -r requirement.txt (line 9)) (6.0.3)
# Requirement already satisfied: python-dotenv in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from -r requirement.txt (line 10)) (1.2.1)
# Requirement already satisfied: ydata-profiling in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from -r requirement.txt (line 11)) (4.17.0)
# Requirement already satisfied: statsmodels in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from -r requirement.txt (line 12)) (0.14.5)
# Requirement already satisfied: ipython in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from -r requirement.txt (line 13)) (9.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from pandas->-r requirement.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from pandas->-r requirement.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from pandas->-r requirement.txt (line 2)) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from scikit-learn->-r requirement.txt (line 3)) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from scikit-learn->-r requirement.txt (line 3)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from matplotlib->-r requirement.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from matplotlib->-r requirement.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from matplotlib->-r requirement.txt (line 5)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from matplotlib->-r requirement.txt (line 5)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from matplotlib->-r requirement.txt (line 5)) (25.0)
# Requirement already satisfied: pillow>=8 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from matplotlib->-r requirement.txt (line 5)) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from matplotlib->-r requirement.txt (line 5)) (3.2.5)
# Requirement already satisfied: narwhals>=1.15.1 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from plotly->-r requirement.txt (line 7)) (2.11.0)
# Requirement already satisfied: pydantic>=2 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ydata-profiling->-r requirement.txt (line 11)) (2.12.4)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ydata-profiling->-r requirement.txt (line 11)) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->-r requirement.txt (line 11)) (0.8.1)
# Requirement already satisfied: minify-html>=0.15.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ydata-profiling->-r requirement.txt (line 11)) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ydata-profiling->-r requirement.txt (line 11)) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.11.1 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ydata-profiling->-r requirement.txt (line 11)) (0.12.5)
# Requirement already satisfied: requests<3,>=2.24.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ydata-profiling->-r requirement.txt (line 11)) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.48.2 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ydata-profiling->-r requirement.txt (line 11)) (4.67.1)
# Requirement already satisfied: multimethod<2,>=1.4 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ydata-profiling->-r requirement.txt (line 11)) (1.12)
# Requirement already satisfied: typeguard<5,>=3 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ydata-profiling->-r requirement.txt (line 11)) (4.4.4)
# Requirement already satisfied: imagehash==4.3.1 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ydata-profiling->-r requirement.txt (line 11)) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ydata-profiling->-r requirement.txt (line 11)) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ydata-profiling->-r requirement.txt (line 11)) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ydata-profiling->-r requirement.txt (line 11)) (0.61.0)
# Requirement already satisfied: PyWavelets in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from imagehash==4.3.1->ydata-profiling->-r requirement.txt (line 11)) (1.9.0)
# Requirement already satisfied: patsy>=0.5.6 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from statsmodels->-r requirement.txt (line 12)) (1.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->-r requirement.txt (line 11)) (3.0.3)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from numba<=0.61,>=0.56.0->ydata-profiling->-r requirement.txt (line 11)) (0.44.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->-r requirement.txt (line 11)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->-r requirement.txt (line 11)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->-r requirement.txt (line 11)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->-r requirement.txt (line 11)) (2025.11.12)
# Requirement already satisfied: colorama in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling->-r requirement.txt (line 11)) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.14.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from typeguard<5,>=3->ydata-profiling->-r requirement.txt (line 11)) (4.15.0)
# Requirement already satisfied: attrs>=19.3.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->-r requirement.txt (line 11)) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->-r requirement.txt (line 11)) (3.5)
# Requirement already satisfied: puremagic in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->-r requirement.txt (line 11)) (1.30)
# Requirement already satisfied: decorator>=4.3.2 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ipython->-r requirement.txt (line 13)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ipython->-r requirement.txt (line 13)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ipython->-r requirement.txt (line 13)) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ipython->-r requirement.txt (line 13)) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ipython->-r requirement.txt (line 13)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ipython->-r requirement.txt (line 13)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ipython->-r requirement.txt (line 13)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from ipython->-r requirement.txt (line 13)) (5.14.3)
# Requirement already satisfied: wcwidth in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->-r requirement.txt (line 13)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from jedi>=0.18.1->ipython->-r requirement.txt (line 13)) (0.8.5)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from pydantic>=2->ydata-profiling->-r requirement.txt (line 11)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from pydantic>=2->ydata-profiling->-r requirement.txt (line 11)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from pydantic>=2->ydata-profiling->-r requirement.txt (line 11)) (0.4.2)
# Requirement already satisfied: six>=1.5 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirement.txt (line 2)) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from stack_data>=0.6.0->ipython->-r requirement.txt (line 13)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from stack_data>=0.6.0->ipython->-r requirement.txt (line 13)) (3.0.0)
# Requirement already satisfied: pure-eval in d:\minestudy\ml\ml with zuu\project based learning course\03\01\pipeline\.venv\lib\site-packages (from stack_data>=0.6.0->ipython->-r requirement.txt (line 13)) (0.2.3)

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder

# %% [markdown]
# ### 1. Loading and Exploring data

# %%
df = pd.read_csv('data/processed/aOvRUrcRLE.csv')
df.head()
# Out:
#   Geography  Gender      Age  ...  EstimatedSalary  Exited  CreditScoreBins
# 0    France  Female  3.76120  ...        101348.88       1             Fair
# 1     Spain  Female  3.73767  ...        112542.58       0             Fair
# 2    France  Female  3.76120  ...        113931.57       1             Poor
# 3    France  Female  3.68668  ...         93826.63       0             Good
# 4     Spain  Female  3.78419  ...         79084.10       0        Excellent
#
# [5 rows x 11 columns]

# %% [markdown]
# ### 2. Build Scikit-learn Pipelines

# %%
remainder_features = ['NumOfProducts','HasCrCard','IsActiveMember','Exited']
numerical_features =['Age','Tenure','Balance','EstimatedSalary']
nominal_features = ['Gender', 'Geography']
ordinal_features = ['CreditScoreBins']

# Clean and scale numerical features (impute with median → standardize)
numerical_transformer = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ]
)

# Nominal categorical preprocessing: handle missing values and create dummy variables
nominal_transformer = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),  # Fill NaN with 'missing'
        ('encoder', OneHotEncoder())  # Convert categories to binary columns
    ]
)

# Ordinal categorical preprocessing: handle missing values and convert to ranked numbers
ordinal_transformer = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),  # Fill missing values
        ('encoder', OrdinalEncoder())  # Categories → integers (preserving order)
    ]
)


# Master preprocessor: routes each column type to its appropriate transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),  # Impute + Scale numbers
        ('nom', nominal_transformer, nominal_features),      # Impute + OneHotEncode
        ('ord', ordinal_transformer, ordinal_features)       # Impute + OrdinalEncode
    ],
    remainder='drop'  # Ignore columns not specified
)


nominal_features_names = []
for feature in nominal_features:
    unique_values = df[feature].unique()
    nominal_features_names.extend([f"{feature}_{val}" for val in unique_values])

df_cp = df.copy()
df_transformed = pd.DataFrame(
    preprocessor.fit_transform(df_cp),
    columns=numerical_features+nominal_features_names+ordinal_features
)
df_remainder = df[remainder_features]
df_pp = pd.concat(
        [df_transformed,df_remainder], 
        axis=1)

# %%
df_pp.to_csv(
    'data/processed/X_Transformed.csv',
    index=False
)
